# %%
import os
import h5py
import numpy as np
import random
import SimpleITK as sitk
from skimage.transform import resize
from pathlib import Path

# %%
# Configuration
# Input paths
image_root = Path("C:\project\mama-mia\images")
mask_root = Path("C:\project\mama-mia\segmentations/expert")
# Output HDF5 file
output_h5 = Path("../data/processed/mama-mia_selected_slices.h5")
output_h5.parent.mkdir(parents=True, exist_ok=True)

# Selection parameters
ratio = (1, 1)  # positive:negative slice ratio
min_tumor_pixels = 20  # at least this many pixels in mask -> positive slice
min_image_std = 0.05  # minimum std-dev for negative
max_slice_distance = 10  # max distance from tumor slices for negatives
fallback_ratio = 0.3  # for patients without any tumor slices
seed = 42
random.seed(seed)

# Volume preprocessing
DESIRED_PHASES = 6  # number of phases/channels to keep (pad or truncate)
new_spacing = (1.0, 1.0, 1.0)
linear_interp = sitk.sitkLinear
nearest_interp = sitk.sitkNearestNeighbor

# Output slice shape
target_shape = (128, 128)  # (height, width)

# %%
# Helper Functions
def resample_image(itk_image, spacing, interpolator):
    """
    Resample a SimpleITK image to isotropic spacing.
    """
    orig_size = itk_image.GetSize()
    orig_spacing = itk_image.GetSpacing()
    new_size = [
        int(round(orig_size[i] * (orig_spacing[i] / spacing[i])))
        for i in range(3)
    ]
    resampler = sitk.ResampleImageFilter()
    resampler.SetOutputSpacing(spacing)
    resampler.SetSize(new_size)
    resampler.SetOutputOrigin(itk_image.GetOrigin())
    resampler.SetOutputDirection(itk_image.GetDirection())
    resampler.SetInterpolator(interpolator)
    return resampler.Execute(itk_image)

# %%
# Gather Patients
image_files = list(image_root.rglob("*.nii*"))
mask_files = list(mask_root.rglob("*.nii*"))

images_by_patient = {}
for img in image_files:
    pid = img.parent.name.lower()
    images_by_patient.setdefault(pid, []).append(img)

masks_by_patient = {}
for m in mask_files:
    pid = m.name.split('.')[0].lower()
    masks_by_patient[pid] = m

patients = [pid for pid in images_by_patient if pid in masks_by_patient]
print(f"Found {len(patients)} patients with both images and masks.")
# Out:
# Found 1506 patients with both images and masks.

# %%
# Determine Slice Dimensions
# Use first patient's first phase to get dimensions
test_img = sitk.ReadImage(str(images_by_patient[patients[0]][0]))
res_test = resample_image(test_img, new_spacing, linear_interp)
h, w = sitk.GetArrayFromImage(res_test).shape[1:]
if target_shape:
    h, w = target_shape

# %%
# Create Extensible HDF5 Datasets
h5f = h5py.File(output_h5, "w")
img_ds = h5f.create_dataset(
    "images", shape=(0, DESIRED_PHASES, h, w), maxshape=(None, DESIRED_PHASES, h, w),
    dtype="float32", chunks=(1, DESIRED_PHASES, h, w)
)
mask_ds = h5f.create_dataset(
    "masks", shape=(0, 1, h, w), maxshape=(None, 1, h, w),
    dtype="uint8", chunks=(1, 1, h, w)
)

# %%
# Append Utility
plural = lambda n, s: f"{n} {s}" + ("s" if n!=1 else "")
def append_slices(images, masks):
    """
    Append new batches of images and masks to HDF5 datasets.
    """
    n_new = images.shape[0]
    old_n = img_ds.shape[0]
    img_ds.resize(old_n + n_new, axis=0)
    mask_ds.resize(old_n + n_new, axis=0)
    img_ds[old_n:old_n + n_new, ...] = images
    mask_ds[old_n:old_n + n_new, ...] = masks
    print(f"  -> Dataset resized: now {old_n + n_new} total slices.")

# %%
def select_negative_slices(volumes, mask_arr, tumor_slices, ratio, min_image_std, Z, fallback_ratio, max_slice_distance):
    """
    Select negative slice indices for training:
    - Close to tumors to capture ample breast tissue (not mostly background)
    - High-contrast slices to avoid uniform or noisy images
    - Fallback: highest-contrast slices when no tumors exist
    """
    neg_candidates = []
    for z in range(Z):
        # Skip slices that contain tumor or already have any mask present
        if z in tumor_slices or mask_arr[z].sum() > 0:
            continue
        # Compute standard deviation (contrast) of the slice
        std_val = volumes[0][z].std()
        # Skip if the slice is too uniform (low contrast)
        if std_val < min_image_std:
            continue
        # Compute the minimum distance (in slices) to any tumor slice; infinite if no tumors
        dist = min(abs(z - t) for t in tumor_slices) if tumor_slices else np.inf
        # Assign a score: only positive if within max_slice_distance, higher when closer
        score = (max_slice_distance - dist) if dist <= max_slice_distance else 0
        neg_candidates.append((z, std_val, score))

    # Sort candidates by descending score first, then by descending contrast
    neg_candidates.sort(key=lambda x: (-x[2], -x[1]))

    if tumor_slices:
        # If there are tumors, choose negatives in proportion to number of tumor slices (ratio[1]/ratio[0])
        desired_neg = ratio[1] * len(tumor_slices) // ratio[0]
        # First take slices with positive score (within defined radius)
        selected = [c for c in neg_candidates if c[2] > 0][:desired_neg]

        # If not enough, fill up with out-of-range slices (score == 0), sorted by highest contrast
        if len(selected) < desired_neg:
            extras = [c for c in neg_candidates if c[2] == 0]
            extras.sort(key=lambda x: -x[1])
            selected += extras[:desired_neg - len(selected)]

        return {z for z, *_ in selected}
    else:
        # Fallback when there are no tumor slices (e.g., healthy subjects)
        # Pick a fixed number of highest-contrast slices
        fb_count = max(1, int(Z * fallback_ratio))
        background = [
            (z, volumes[0][z].std())
            for z in range(Z)
            if mask_arr[z].sum() == 0 # only slices without any mask
        ]
        # Sort descending by contrast
        background.sort(key=lambda x: -x[1])
        return {z for z, _ in background[:fb_count]}

# %%
# Process and Write Slices
total_written = 0
print("Processing patients and writing slices...")
for idx_pid, pid in enumerate(patients, start=1):
    print(f"Processing patient {idx_pid}/{len(patients)}: '{pid}'")
    # Load and preprocess volumes
    volumes = []
    for img_path in sorted(images_by_patient[pid]):
        img = sitk.ReadImage(str(img_path))
        res_img = resample_image(img, new_spacing, linear_interp)
        arr = sitk.GetArrayFromImage(res_img).astype(np.float32)
        arr = (arr - arr.mean()) / (arr.std() + 1e-8)
        volumes.append(arr)

    # Load and preprocess mask
    m = sitk.ReadImage(str(masks_by_patient[pid]))
    res_m = resample_image(m, new_spacing, nearest_interp)
    mask_arr = sitk.GetArrayFromImage(res_m).astype(np.uint8)

    Z = volumes[0].shape[0]
    # Identify positive slices
    tumor_slices = [z for z in range(Z) if mask_arr[z].sum() >= min_tumor_pixels]

    # Identify negative slices via helper function
    neg_slices = select_negative_slices(
        volumes, mask_arr, tumor_slices,
        ratio, min_image_std, Z, fallback_ratio,
        max_slice_distance
    )

    print(f"  Found {len(tumor_slices)} positive and {len(neg_slices)} negative slices.")

    # Build batch for this patient
    selected_indices = tumor_slices + sorted(neg_slices)
    n_sel = len(selected_indices)
    batch_imgs = np.zeros((n_sel, DESIRED_PHASES, h, w), dtype=np.float32)
    batch_masks = np.zeros((n_sel, 1, h, w), dtype=np.uint8)

    for i, z in enumerate(selected_indices, start=1):
        # Stack phases and pad
        stack = np.stack([vol[z] for vol in volumes], axis=0)
        if stack.shape[0] < DESIRED_PHASES:
            pad_w = ((0, DESIRED_PHASES - stack.shape[0]), (0, 0), (0, 0))
            stack = np.pad(stack, pad_w, mode='constant')
        else:
            stack = stack[:DESIRED_PHASES]
        # Resize
        if target_shape:
            resized = np.zeros((DESIRED_PHASES, h, w), dtype=np.float32)
            for c in range(DESIRED_PHASES):
                resized[c] = resize(stack[c], (h, w), order=1, preserve_range=True)
            stack = resized

        mask_slice = mask_arr[z]
        if target_shape:
            mask_slice = resize(mask_slice, (h, w), order=0, preserve_range=True).astype(np.uint8)

        batch_imgs[i-1] = stack
        batch_masks[i-1, 0] = mask_slice
        print(f"    Processing slice {i}/{n_sel} (index={z})", end='\r')

    print()  # newline after slice loop

    # Append this patient's batch
    append_slices(batch_imgs, batch_masks)
    total_written += n_sel
    print(f"  Appended {n_sel} slices for patient '{pid}' (total written: {total_written}).\n")

h5f.close()
print("HDF5 container creation complete.")
# Out:
# Processing patients and writing slices...
# Processing patient 1/1506: 'duke_001'
#   Found 20 positives and 20 negatives slices.
#     Processing slice 40/40 (index=84)
#   -> Dataset resized: now 40 total slices.
#   Appended 40 slices for patient 'duke_001' (total written: 40).
#
# Processing patient 2/1506: 'duke_002'
#   Found 14 positives and 14 negatives slices.
#     Processing slice 28/28 (index=113)
#   -> Dataset resized: now 68 total slices.
#   Appended 28 slices for patient 'duke_002' (total written: 68).
#
# Processing patient 3/1506: 'duke_005'
#   Found 47 positives and 47 negatives slices.
#     Processing slice 94/94 (index=136)
#   -> Dataset resized: now 162 total slices.
#   Appended 94 slices for patient 'duke_005' (total written: 162).
#
# Processing patient 4/1506: 'duke_009'
#   Found 25 positives and 25 negatives slices.
#     Processing slice 50/50 (index=115)
#   -> Dataset resized: now 212 total slices.
#   Appended 50 slices for patient 'duke_009' (total written: 212).
#
# Processing patient 5/1506: 'duke_010'
#   Found 28 positives and 28 negatives slices.
#     Processing slice 56/56 (index=62)
#   -> Dataset resized: now 268 total slices.
#   Appended 56 slices for patient 'duke_010' (total written: 268).
#
# Processing patient 6/1506: 'duke_012'
#   Found 59 positives and 59 negatives slices.
#     Processing slice 118/118 (index=164)
#   -> Dataset resized: now 386 total slices.
#   Appended 118 slices for patient 'duke_012' (total written: 386).
#
# Processing patient 7/1506: 'duke_019'
#   Found 37 positives and 37 negatives slices.
#     Processing slice 74/74 (index=115)
#   -> Dataset resized: now 460 total slices.
#   Appended 74 slices for patient 'duke_019' (total written: 460).
#
# Processing patient 8/1506: 'duke_021'
#   Found 18 positives and 18 negatives slices.
#     Processing slice 36/36 (index=71)
#   -> Dataset resized: now 496 total slices.
#   Appended 36 slices for patient 'duke_021' (total written: 496).
#
# Processing patient 9/1506: 'duke_022'
#   Found 33 positives and 33 negatives slices.
#     Processing slice 66/66 (index=130)
#   -> Dataset resized: now 562 total slices.
#   Appended 66 slices for patient 'duke_022' (total written: 562).
#
# Processing patient 10/1506: 'duke_028'
#   Found 69 positives and 69 negatives slices.
#     Processing slice 138/138 (index=179)
#   -> Dataset resized: now 700 total slices.
#   Appended 138 slices for patient 'duke_028' (total written: 700).
#
# Processing patient 11/1506: 'duke_032'
#   Found 16 positives and 16 negatives slices.
#     Processing slice 32/32 (index=76)
#   -> Dataset resized: now 732 total slices.
#   Appended 32 slices for patient 'duke_032' (total written: 732).
#
# Processing patient 12/1506: 'duke_034'
#   Found 49 positives and 49 negatives slices.
#     Processing slice 98/98 (index=129)
#   -> Dataset resized: now 830 total slices.
#   Appended 98 slices for patient 'duke_034' (total written: 830).
#
# Processing patient 13/1506: 'duke_040'
#   Found 37 positives and 37 negatives slices.
#     Processing slice 74/74 (index=109)
#   -> Dataset resized: now 904 total slices.
#   Appended 74 slices for patient 'duke_040' (total written: 904).
#
# Processing patient 14/1506: 'duke_041'
#   Found 32 positives and 32 negatives slices.
#     Processing slice 64/64 (index=108)
#   -> Dataset resized: now 968 total slices.
#   Appended 64 slices for patient 'duke_041' (total written: 968).
#
# Processing patient 15/1506: 'duke_043'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=93)
#   -> Dataset resized: now 1026 total slices.
#   Appended 58 slices for patient 'duke_043' (total written: 1026).
#
# Processing patient 16/1506: 'duke_044'
#   Found 15 positives and 15 negatives slices.
#     Processing slice 30/30 (index=69)
#   -> Dataset resized: now 1056 total slices.
#   Appended 30 slices for patient 'duke_044' (total written: 1056).
#
# Processing patient 17/1506: 'duke_045'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=144)
#   -> Dataset resized: now 1114 total slices.
#   Appended 58 slices for patient 'duke_045' (total written: 1114).
#
# Processing patient 18/1506: 'duke_046'
#   Found 77 positives and 77 negatives slices.
#     Processing slice 154/154 (index=207)
#   -> Dataset resized: now 1268 total slices.
#   Appended 154 slices for patient 'duke_046' (total written: 1268).
#
# Processing patient 19/1506: 'duke_048'
#   Found 21 positives and 21 negatives slices.
#     Processing slice 42/42 (index=96)
#   -> Dataset resized: now 1310 total slices.
#   Appended 42 slices for patient 'duke_048' (total written: 1310).
#
# Processing patient 20/1506: 'duke_051'
#   Found 8 positives and 8 negatives slices.
#     Processing slice 16/16 (index=102)
#   -> Dataset resized: now 1326 total slices.
#   Appended 16 slices for patient 'duke_051' (total written: 1326).
#
# Processing patient 21/1506: 'duke_055'
#   Found 14 positives and 14 negatives slices.
#     Processing slice 28/28 (index=118)
#   -> Dataset resized: now 1354 total slices.
#   Appended 28 slices for patient 'duke_055' (total written: 1354).
#
# Processing patient 22/1506: 'duke_057'
#   Found 85 positives and 83 negatives slices.
#   Processing slice 92/168 (index=6)    Processing slice 123/168 (index=122)    Processing slice 153/168 (index=152)
#   -> Dataset resized: now 1522 total slices.
#   Appended 168 slices for patient 'duke_057' (total written: 1522).
#
# Processing patient 23/1506: 'duke_059'
#   Found 14 positives and 14 negatives slices.
#     Processing slice 28/28 (index=110)
#   -> Dataset resized: now 1550 total slices.
#   Appended 28 slices for patient 'duke_059' (total written: 1550).
#
# Processing patient 24/1506: 'duke_060'
#   Found 20 positives and 20 negatives slices.
#     Processing slice 40/40 (index=77)
#   -> Dataset resized: now 1590 total slices.
#   Appended 40 slices for patient 'duke_060' (total written: 1590).
#
# Processing patient 25/1506: 'duke_061'
#   Found 42 positives and 42 negatives slices.
#     Processing slice 84/84 (index=122)
#   -> Dataset resized: now 1674 total slices.
#   Appended 84 slices for patient 'duke_061' (total written: 1674).
#
# Processing patient 26/1506: 'duke_064'
#   Found 17 positives and 17 negatives slices.
#     Processing slice 34/34 (index=105)
#   -> Dataset resized: now 1708 total slices.
#   Appended 34 slices for patient 'duke_064' (total written: 1708).
#
# Processing patient 27/1506: 'duke_069'
#   Found 17 positives and 17 negatives slices.
#     Processing slice 34/34 (index=91)
#   -> Dataset resized: now 1742 total slices.
#   Appended 34 slices for patient 'duke_069' (total written: 1742).
#
# Processing patient 28/1506: 'duke_071'
#   Found 23 positives and 23 negatives slices.
#     Processing slice 46/46 (index=134)
#   -> Dataset resized: now 1788 total slices.
#   Appended 46 slices for patient 'duke_071' (total written: 1788).
#
# Processing patient 29/1506: 'duke_077'
#   Found 31 positives and 31 negatives slices.
#     Processing slice 62/62 (index=129)
#   -> Dataset resized: now 1850 total slices.
#   Appended 62 slices for patient 'duke_077' (total written: 1850).
#
# Processing patient 30/1506: 'duke_082'
#   Found 32 positives and 32 negatives slices.
#     Processing slice 64/64 (index=110)
#   -> Dataset resized: now 1914 total slices.
#   Appended 64 slices for patient 'duke_082' (total written: 1914).
#
# Processing patient 31/1506: 'duke_086'
#   Found 74 positives and 74 negatives slices.
#     Processing slice 148/148 (index=164)
#   -> Dataset resized: now 2062 total slices.
#   Appended 148 slices for patient 'duke_086' (total written: 2062).
#
# Processing patient 32/1506: 'duke_090'
#   Found 114 positives and 78 negatives slices.
#    Processing slice 124/192 (index=9)    Processing slice 154/192 (index=157)    Processing slice 183/192 (index=186)
#   -> Dataset resized: now 2254 total slices.
#   Appended 192 slices for patient 'duke_090' (total written: 2254).
#
# Processing patient 33/1506: 'duke_091'
#   Found 51 positives and 51 negatives slices.
#     Processing slice 102/102 (index=114)
#   -> Dataset resized: now 2356 total slices.
#   Appended 102 slices for patient 'duke_091' (total written: 2356).
#
# Processing patient 34/1506: 'duke_097'
#   Found 39 positives and 39 negatives slices.
#     Processing slice 78/78 (index=119)
#   -> Dataset resized: now 2434 total slices.
#   Appended 78 slices for patient 'duke_097' (total written: 2434).
#
# Processing patient 35/1506: 'duke_099'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=97)
#   -> Dataset resized: now 2482 total slices.
#   Appended 48 slices for patient 'duke_099' (total written: 2482).
#
# Processing patient 36/1506: 'duke_101'
#   Found 21 positives and 21 negatives slices.
#     Processing slice 42/42 (index=106)
#   -> Dataset resized: now 2524 total slices.
#   Appended 42 slices for patient 'duke_101' (total written: 2524).
#
# Processing patient 37/1506: 'duke_103'
#   Found 18 positives and 18 negatives slices.
#     Processing slice 36/36 (index=138)
#   -> Dataset resized: now 2560 total slices.
#   Appended 36 slices for patient 'duke_103' (total written: 2560).
#
# Processing patient 38/1506: 'duke_104'
#   Found 15 positives and 15 negatives slices.
#     Processing slice 30/30 (index=53)
#   -> Dataset resized: now 2590 total slices.
#   Appended 30 slices for patient 'duke_104' (total written: 2590).
#
# Processing patient 39/1506: 'duke_105'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=102)
#   -> Dataset resized: now 2648 total slices.
#   Appended 58 slices for patient 'duke_105' (total written: 2648).
#
# Processing patient 40/1506: 'duke_107'
#   Found 23 positives and 23 negatives slices.
#     Processing slice 46/46 (index=147)
#   -> Dataset resized: now 2694 total slices.
#   Appended 46 slices for patient 'duke_107' (total written: 2694).
#
# Processing patient 41/1506: 'duke_114'
#   Found 17 positives and 17 negatives slices.
#     Processing slice 34/34 (index=78)
#   -> Dataset resized: now 2728 total slices.
#   Appended 34 slices for patient 'duke_114' (total written: 2728).
#
# Processing patient 42/1506: 'duke_115'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=72)
#   -> Dataset resized: now 2776 total slices.
#   Appended 48 slices for patient 'duke_115' (total written: 2776).
#
# Processing patient 43/1506: 'duke_116'
#   Found 34 positives and 34 negatives slices.
#     Processing slice 68/68 (index=134)
#   -> Dataset resized: now 2844 total slices.
#   Appended 68 slices for patient 'duke_116' (total written: 2844).
#
# Processing patient 44/1506: 'duke_117'
#   Found 21 positives and 21 negatives slices.
#     Processing slice 42/42 (index=165)
#   -> Dataset resized: now 2886 total slices.
#   Appended 42 slices for patient 'duke_117' (total written: 2886).
#
# Processing patient 45/1506: 'duke_119'
#   Found 71 positives and 71 negatives slices.
#     Processing slice 142/142 (index=149)
#   -> Dataset resized: now 3028 total slices.
#   Appended 142 slices for patient 'duke_119' (total written: 3028).
#
# Processing patient 46/1506: 'duke_120'
#   Found 20 positives and 20 negatives slices.
#     Processing slice 40/40 (index=55)
#   -> Dataset resized: now 3068 total slices.
#   Appended 40 slices for patient 'duke_120' (total written: 3068).
#
# Processing patient 47/1506: 'duke_123'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=78)
#   -> Dataset resized: now 3116 total slices.
#   Appended 48 slices for patient 'duke_123' (total written: 3116).
#
# Processing patient 48/1506: 'duke_129'
#   Found 14 positives and 14 negatives slices.
#     Processing slice 28/28 (index=90)
#   -> Dataset resized: now 3144 total slices.
#   Appended 28 slices for patient 'duke_129' (total written: 3144).
#
# Processing patient 49/1506: 'duke_132'
#   Found 17 positives and 17 negatives slices.
#     Processing slice 34/34 (index=141)
#   -> Dataset resized: now 3178 total slices.
#   Appended 34 slices for patient 'duke_132' (total written: 3178).
#
# Processing patient 50/1506: 'duke_134'
#   Found 14 positives and 14 negatives slices.
#     Processing slice 28/28 (index=123)
#   -> Dataset resized: now 3206 total slices.
#   Appended 28 slices for patient 'duke_134' (total written: 3206).
#
# Processing patient 51/1506: 'duke_136'
#   Found 12 positives and 12 negatives slices.
#     Processing slice 24/24 (index=35)
#   -> Dataset resized: now 3230 total slices.
#   Appended 24 slices for patient 'duke_136' (total written: 3230).
#
# Processing patient 52/1506: 'duke_137'
#   Found 25 positives and 25 negatives slices.
#     Processing slice 50/50 (index=83)
#   -> Dataset resized: now 3280 total slices.
#   Appended 50 slices for patient 'duke_137' (total written: 3280).
#
# Processing patient 53/1506: 'duke_141'
#   Found 22 positives and 22 negatives slices.
#     Processing slice 44/44 (index=106)
#   -> Dataset resized: now 3324 total slices.
#   Appended 44 slices for patient 'duke_141' (total written: 3324).
#
# Processing patient 54/1506: 'duke_142'
#   Found 10 positives and 10 negatives slices.
#     Processing slice 20/20 (index=88)
#   -> Dataset resized: now 3344 total slices.
#   Appended 20 slices for patient 'duke_142' (total written: 3344).
#
# Processing patient 55/1506: 'duke_144'
#   Found 26 positives and 26 negatives slices.
#     Processing slice 52/52 (index=105)
#   -> Dataset resized: now 3396 total slices.
#   Appended 52 slices for patient 'duke_144' (total written: 3396).
#
# Processing patient 56/1506: 'duke_148'
#   Found 68 positives and 68 negatives slices.
#     Processing slice 136/136 (index=137)
#   -> Dataset resized: now 3532 total slices.
#   Appended 136 slices for patient 'duke_148' (total written: 3532).
#
# Processing patient 57/1506: 'duke_150'
#   Found 48 positives and 48 negatives slices.
#     Processing slice 96/96 (index=113)
#   -> Dataset resized: now 3628 total slices.
#   Appended 96 slices for patient 'duke_150' (total written: 3628).
#
# Processing patient 58/1506: 'duke_156'
#   Found 33 positives and 33 negatives slices.
#     Processing slice 66/66 (index=150)
#   -> Dataset resized: now 3694 total slices.
#   Appended 66 slices for patient 'duke_156' (total written: 3694).
#
# Processing patient 59/1506: 'duke_157'
#   Found 31 positives and 31 negatives slices.
#     Processing slice 62/62 (index=84)
#   -> Dataset resized: now 3756 total slices.
#   Appended 62 slices for patient 'duke_157' (total written: 3756).
#
# Processing patient 60/1506: 'duke_160'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=100)
#   -> Dataset resized: now 3804 total slices.
#   Appended 48 slices for patient 'duke_160' (total written: 3804).
#
# Processing patient 61/1506: 'duke_163'
#   Found 42 positives and 42 negatives slices.
#     Processing slice 84/84 (index=125)
#   -> Dataset resized: now 3888 total slices.
#   Appended 84 slices for patient 'duke_163' (total written: 3888).
#
# Processing patient 62/1506: 'duke_167'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=105)
#   -> Dataset resized: now 3946 total slices.
#   Appended 58 slices for patient 'duke_167' (total written: 3946).
#
# Processing patient 63/1506: 'duke_168'
#   Found 17 positives and 17 negatives slices.
#     Processing slice 34/34 (index=126)
#   -> Dataset resized: now 3980 total slices.
#   Appended 34 slices for patient 'duke_168' (total written: 3980).
#
# Processing patient 64/1506: 'duke_176'
#   Found 21 positives and 21 negatives slices.
#     Processing slice 42/42 (index=138)
#   -> Dataset resized: now 4022 total slices.
#   Appended 42 slices for patient 'duke_176' (total written: 4022).
#
# Processing patient 65/1506: 'duke_177'
#   Found 14 positives and 14 negatives slices.
#     Processing slice 28/28 (index=115)
#   -> Dataset resized: now 4050 total slices.
#   Appended 28 slices for patient 'duke_177' (total written: 4050).
#
# Processing patient 66/1506: 'duke_178'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=137)
#   -> Dataset resized: now 4108 total slices.
#   Appended 58 slices for patient 'duke_178' (total written: 4108).
#
# Processing patient 67/1506: 'duke_180'
#   Found 36 positives and 36 negatives slices.
#     Processing slice 72/72 (index=111)
#   -> Dataset resized: now 4180 total slices.
#   Appended 72 slices for patient 'duke_180' (total written: 4180).
#
# Processing patient 68/1506: 'duke_183'
#   Found 18 positives and 18 negatives slices.
#     Processing slice 36/36 (index=130)
#   -> Dataset resized: now 4216 total slices.
#   Appended 36 slices for patient 'duke_183' (total written: 4216).
#
# Processing patient 69/1506: 'duke_185'
#   Found 79 positives and 79 negatives slices.
#     Processing slice 158/158 (index=180)
#   -> Dataset resized: now 4374 total slices.
#   Appended 158 slices for patient 'duke_185' (total written: 4374).
#
# Processing patient 70/1506: 'duke_189'
#   Found 34 positives and 34 negatives slices.
#     Processing slice 68/68 (index=85)
#   -> Dataset resized: now 4442 total slices.
#   Appended 68 slices for patient 'duke_189' (total written: 4442).
#
# Processing patient 71/1506: 'duke_192'
#   Found 36 positives and 36 negatives slices.
#     Processing slice 72/72 (index=105)
#   -> Dataset resized: now 4514 total slices.
#   Appended 72 slices for patient 'duke_192' (total written: 4514).
#
# Processing patient 72/1506: 'duke_198'
#   Found 51 positives and 51 negatives slices.
#     Processing slice 102/102 (index=107)
#   -> Dataset resized: now 4616 total slices.
#   Appended 102 slices for patient 'duke_198' (total written: 4616).
#
# Processing patient 73/1506: 'duke_202'
#   Found 40 positives and 40 negatives slices.
#     Processing slice 80/80 (index=122)
#   -> Dataset resized: now 4696 total slices.
#   Appended 80 slices for patient 'duke_202' (total written: 4696).
#
# Processing patient 74/1506: 'duke_205'
#   Found 55 positives and 55 negatives slices.
#     Processing slice 110/110 (index=114)
#   -> Dataset resized: now 4806 total slices.
#   Appended 110 slices for patient 'duke_205' (total written: 4806).
#
# Processing patient 75/1506: 'duke_211'
#   Found 25 positives and 25 negatives slices.
#     Processing slice 50/50 (index=111)
#   -> Dataset resized: now 4856 total slices.
#   Appended 50 slices for patient 'duke_211' (total written: 4856).
#
# Processing patient 76/1506: 'duke_217'
#   Found 47 positives and 47 negatives slices.
#     Processing slice 94/94 (index=98)
#   -> Dataset resized: now 4950 total slices.
#   Appended 94 slices for patient 'duke_217' (total written: 4950).
#
# Processing patient 77/1506: 'duke_218'
#   Found 23 positives and 23 negatives slices.
#     Processing slice 46/46 (index=121)
#   -> Dataset resized: now 4996 total slices.
#   Appended 46 slices for patient 'duke_218' (total written: 4996).
#
# Processing patient 78/1506: 'duke_225'
#   Found 59 positives and 59 negatives slices.
#     Processing slice 118/118 (index=117)   Processing slice 67/118 (index=7)    Processing slice 102/118 (index=42)
#   -> Dataset resized: now 5114 total slices.
#   Appended 118 slices for patient 'duke_225' (total written: 5114).
#
# Processing patient 79/1506: 'duke_228'
#   Found 38 positives and 38 negatives slices.
#     Processing slice 76/76 (index=150)
#   -> Dataset resized: now 5190 total slices.
#   Appended 76 slices for patient 'duke_228' (total written: 5190).
#
# Processing patient 80/1506: 'duke_233'
#   Found 16 positives and 16 negatives slices.
#     Processing slice 32/32 (index=123)
#   -> Dataset resized: now 5222 total slices.
#   Appended 32 slices for patient 'duke_233' (total written: 5222).
#
# Processing patient 81/1506: 'duke_234'
#   Found 47 positives and 47 negatives slices.
#     Processing slice 94/94 (index=141)
#   -> Dataset resized: now 5316 total slices.
#   Appended 94 slices for patient 'duke_234' (total written: 5316).
#
# Processing patient 82/1506: 'duke_236'
#   Found 54 positives and 54 negatives slices.
#     Processing slice 108/108 (index=129)
#   -> Dataset resized: now 5424 total slices.
#   Appended 108 slices for patient 'duke_236' (total written: 5424).
#
# Processing patient 83/1506: 'duke_237'
#   Found 35 positives and 35 negatives slices.
#     Processing slice 70/70 (index=112)
#   -> Dataset resized: now 5494 total slices.
#   Appended 70 slices for patient 'duke_237' (total written: 5494).
#
# Processing patient 84/1506: 'duke_239'
#   Found 22 positives and 22 negatives slices.
#     Processing slice 44/44 (index=93)
#   -> Dataset resized: now 5538 total slices.
#   Appended 44 slices for patient 'duke_239' (total written: 5538).
#
# Processing patient 85/1506: 'duke_240'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=130)
#   -> Dataset resized: now 5596 total slices.
#   Appended 58 slices for patient 'duke_240' (total written: 5596).
#
# Processing patient 86/1506: 'duke_244'
#   Found 27 positives and 27 negatives slices.
#     Processing slice 54/54 (index=80)
#   -> Dataset resized: now 5650 total slices.
#   Appended 54 slices for patient 'duke_244' (total written: 5650).
#
# Processing patient 87/1506: 'duke_250'
#   Found 19 positives and 19 negatives slices.
#     Processing slice 38/38 (index=172)
#   -> Dataset resized: now 5688 total slices.
#   Appended 38 slices for patient 'duke_250' (total written: 5688).
#
# Processing patient 88/1506: 'duke_253'
#   Found 14 positives and 14 negatives slices.
#     Processing slice 28/28 (index=84)
#   -> Dataset resized: now 5716 total slices.
#   Appended 28 slices for patient 'duke_253' (total written: 5716).
#
# Processing patient 89/1506: 'duke_255'
#   Found 62 positives and 62 negatives slices.
#     Processing slice 124/124 (index=135)
#   -> Dataset resized: now 5840 total slices.
#   Appended 124 slices for patient 'duke_255' (total written: 5840).
#
# Processing patient 90/1506: 'duke_256'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=94)
#   -> Dataset resized: now 5888 total slices.
#   Appended 48 slices for patient 'duke_256' (total written: 5888).
#
# Processing patient 91/1506: 'duke_258'
#   Found 97 positives and 85 negatives slices.
#     Processing slice 182/182 (index=183)
#   -> Dataset resized: now 6070 total slices.
#   Appended 182 slices for patient 'duke_258' (total written: 6070).
#
# Processing patient 92/1506: 'duke_260'
#   Found 12 positives and 12 negatives slices.
#     Processing slice 24/24 (index=58)
#   -> Dataset resized: now 6094 total slices.
#   Appended 24 slices for patient 'duke_260' (total written: 6094).
#
# Processing patient 93/1506: 'duke_265'
#   Found 31 positives and 31 negatives slices.
#     Processing slice 62/62 (index=77)
#   -> Dataset resized: now 6156 total slices.
#   Appended 62 slices for patient 'duke_265' (total written: 6156).
#
# Processing patient 94/1506: 'duke_268'
#   Found 36 positives and 36 negatives slices.
#     Processing slice 72/72 (index=148)
#   -> Dataset resized: now 6228 total slices.
#   Appended 72 slices for patient 'duke_268' (total written: 6228).
#
# Processing patient 95/1506: 'duke_269'
#   Found 72 positives and 72 negatives slices.
#     Processing slice 144/144 (index=155)
#   -> Dataset resized: now 6372 total slices.
#   Appended 144 slices for patient 'duke_269' (total written: 6372).
#
# Processing patient 96/1506: 'duke_271'
#   Found 33 positives and 33 negatives slices.
#     Processing slice 66/66 (index=97)
#   -> Dataset resized: now 6438 total slices.
#   Appended 66 slices for patient 'duke_271' (total written: 6438).
#
# Processing patient 97/1506: 'duke_275'
#   Found 27 positives and 27 negatives slices.
#     Processing slice 54/54 (index=115)
#   -> Dataset resized: now 6492 total slices.
#   Appended 54 slices for patient 'duke_275' (total written: 6492).
#
# Processing patient 98/1506: 'duke_282'
#   Found 19 positives and 19 negatives slices.
#     Processing slice 38/38 (index=95)
#   -> Dataset resized: now 6530 total slices.
#   Appended 38 slices for patient 'duke_282' (total written: 6530).
#
# Processing patient 99/1506: 'duke_283'
#   Found 17 positives and 17 negatives slices.
#     Processing slice 34/34 (index=73)
#   -> Dataset resized: now 6564 total slices.
#   Appended 34 slices for patient 'duke_283' (total written: 6564).
#
# Processing patient 100/1506: 'duke_285'
#   Found 35 positives and 35 negatives slices.
#     Processing slice 70/70 (index=159)
#   -> Dataset resized: now 6634 total slices.
#   Appended 70 slices for patient 'duke_285' (total written: 6634).
#
# Processing patient 101/1506: 'duke_287'
#   Found 77 positives and 77 negatives slices.
#     Processing slice 154/154 (index=160)
#   -> Dataset resized: now 6788 total slices.
#   Appended 154 slices for patient 'duke_287' (total written: 6788).
#
# Processing patient 102/1506: 'duke_290'
#   Found 16 positives and 16 negatives slices.
#     Processing slice 32/32 (index=136)
#   -> Dataset resized: now 6820 total slices.
#   Appended 32 slices for patient 'duke_290' (total written: 6820).
#
# Processing patient 103/1506: 'duke_293'
#   Found 60 positives and 60 negatives slices.
#     Processing slice 120/120 (index=145)
#   -> Dataset resized: now 6940 total slices.
#   Appended 120 slices for patient 'duke_293' (total written: 6940).
#
# Processing patient 104/1506: 'duke_298'
#   Found 31 positives and 31 negatives slices.
#     Processing slice 62/62 (index=197)
#   -> Dataset resized: now 7002 total slices.
#   Appended 62 slices for patient 'duke_298' (total written: 7002).
#
# Processing patient 105/1506: 'duke_301'
#   Found 20 positives and 20 negatives slices.
#     Processing slice 40/40 (index=145)
#   -> Dataset resized: now 7042 total slices.
#   Appended 40 slices for patient 'duke_301' (total written: 7042).
#
# Processing patient 106/1506: 'duke_303'
#   Found 22 positives and 22 negatives slices.
#     Processing slice 44/44 (index=134)
#   -> Dataset resized: now 7086 total slices.
#   Appended 44 slices for patient 'duke_303' (total written: 7086).
#
# Processing patient 107/1506: 'duke_304'
#   Found 84 positives and 84 negatives slices.
#     Processing slice 168/168 (index=170)
#   -> Dataset resized: now 7254 total slices.
#   Appended 168 slices for patient 'duke_304' (total written: 7254).
#
# Processing patient 108/1506: 'duke_306'
#   Found 14 positives and 14 negatives slices.
#     Processing slice 28/28 (index=106)
#   -> Dataset resized: now 7282 total slices.
#   Appended 28 slices for patient 'duke_306' (total written: 7282).
#
# Processing patient 109/1506: 'duke_307'
#   Found 28 positives and 28 negatives slices.
#     Processing slice 56/56 (index=134)
#   -> Dataset resized: now 7338 total slices.
#   Appended 56 slices for patient 'duke_307' (total written: 7338).
#
# Processing patient 110/1506: 'duke_313'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=111)
#   -> Dataset resized: now 7396 total slices.
#   Appended 58 slices for patient 'duke_313' (total written: 7396).
#
# Processing patient 111/1506: 'duke_317'
#   Found 30 positives and 30 negatives slices.
#     Processing slice 60/60 (index=122)
#   -> Dataset resized: now 7456 total slices.
#   Appended 60 slices for patient 'duke_317' (total written: 7456).
#
# Processing patient 112/1506: 'duke_321'
#   Found 43 positives and 43 negatives slices.
#     Processing slice 86/86 (index=113)
#   -> Dataset resized: now 7542 total slices.
#   Appended 86 slices for patient 'duke_321' (total written: 7542).
#
# Processing patient 113/1506: 'duke_323'
#   Found 17 positives and 17 negatives slices.
#     Processing slice 34/34 (index=93)
#   -> Dataset resized: now 7576 total slices.
#   Appended 34 slices for patient 'duke_323' (total written: 7576).
#
# Processing patient 114/1506: 'duke_328'
#   Found 31 positives and 31 negatives slices.
#     Processing slice 62/62 (index=113)
#   -> Dataset resized: now 7638 total slices.
#   Appended 62 slices for patient 'duke_328' (total written: 7638).
#
# Processing patient 115/1506: 'duke_333'
#   Found 15 positives and 15 negatives slices.
#     Processing slice 30/30 (index=71)
#   -> Dataset resized: now 7668 total slices.
#   Appended 30 slices for patient 'duke_333' (total written: 7668).
#
# Processing patient 116/1506: 'duke_335'
#   Found 36 positives and 36 negatives slices.
#     Processing slice 72/72 (index=93)
#   -> Dataset resized: now 7740 total slices.
#   Appended 72 slices for patient 'duke_335' (total written: 7740).
#
# Processing patient 117/1506: 'duke_338'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=130)
#   -> Dataset resized: now 7798 total slices.
#   Appended 58 slices for patient 'duke_338' (total written: 7798).
#
# Processing patient 118/1506: 'duke_345'
#   Found 22 positives and 22 negatives slices.
#     Processing slice 44/44 (index=104)
#   -> Dataset resized: now 7842 total slices.
#   Appended 44 slices for patient 'duke_345' (total written: 7842).
#
# Processing patient 119/1506: 'duke_346'
#   Found 54 positives and 54 negatives slices.
#     Processing slice 108/108 (index=141)
#   -> Dataset resized: now 7950 total slices.
#   Appended 108 slices for patient 'duke_346' (total written: 7950).
#
# Processing patient 120/1506: 'duke_350'
#   Found 37 positives and 37 negatives slices.
#     Processing slice 74/74 (index=130)
#   -> Dataset resized: now 8024 total slices.
#   Appended 74 slices for patient 'duke_350' (total written: 8024).
#
# Processing patient 121/1506: 'duke_353'
#   Found 31 positives and 31 negatives slices.
#     Processing slice 62/62 (index=111)
#   -> Dataset resized: now 8086 total slices.
#   Appended 62 slices for patient 'duke_353' (total written: 8086).
#
# Processing patient 122/1506: 'duke_356'
#   Found 64 positives and 64 negatives slices.
#     Processing slice 128/128 (index=141)
#   -> Dataset resized: now 8214 total slices.
#   Appended 128 slices for patient 'duke_356' (total written: 8214).
#
# Processing patient 123/1506: 'duke_360'
#   Found 21 positives and 21 negatives slices.
#     Processing slice 42/42 (index=127)
#   -> Dataset resized: now 8256 total slices.
#   Appended 42 slices for patient 'duke_360' (total written: 8256).
#
# Processing patient 124/1506: 'duke_363'
#   Found 34 positives and 34 negatives slices.
#     Processing slice 68/68 (index=131)
#   -> Dataset resized: now 8324 total slices.
#   Appended 68 slices for patient 'duke_363' (total written: 8324).
#
# Processing patient 125/1506: 'duke_368'
#   Found 23 positives and 23 negatives slices.
#     Processing slice 46/46 (index=113)
#   -> Dataset resized: now 8370 total slices.
#   Appended 46 slices for patient 'duke_368' (total written: 8370).
#
# Processing patient 126/1506: 'duke_377'
#   Found 20 positives and 20 negatives slices.
#     Processing slice 40/40 (index=113)
#   -> Dataset resized: now 8410 total slices.
#   Appended 40 slices for patient 'duke_377' (total written: 8410).
#
# Processing patient 127/1506: 'duke_378'
#   Found 34 positives and 34 negatives slices.
#     Processing slice 68/68 (index=116)
#   -> Dataset resized: now 8478 total slices.
#   Appended 68 slices for patient 'duke_378' (total written: 8478).
#
# Processing patient 128/1506: 'duke_383'
#   Found 92 positives and 50 negatives slices.
#     Processing slice 142/142 (index=145)
#   -> Dataset resized: now 8620 total slices.
#   Appended 142 slices for patient 'duke_383' (total written: 8620).
#
# Processing patient 129/1506: 'duke_385'
#   Found 99 positives and 99 negatives slices.
#     Processing slice 198/198 (index=248)
#   -> Dataset resized: now 8818 total slices.
#   Appended 198 slices for patient 'duke_385' (total written: 8818).
#
# Processing patient 130/1506: 'duke_386'
#   Found 33 positives and 33 negatives slices.
#     Processing slice 66/66 (index=133)
#   -> Dataset resized: now 8884 total slices.
#   Appended 66 slices for patient 'duke_386' (total written: 8884).
#
# Processing patient 131/1506: 'duke_387'
#   Found 39 positives and 39 negatives slices.
#     Processing slice 78/78 (index=112)
#   -> Dataset resized: now 8962 total slices.
#   Appended 78 slices for patient 'duke_387' (total written: 8962).
#
# Processing patient 132/1506: 'duke_395'
#   Found 30 positives and 30 negatives slices.
#     Processing slice 60/60 (index=110)
#   -> Dataset resized: now 9022 total slices.
#   Appended 60 slices for patient 'duke_395' (total written: 9022).
#
# Processing patient 133/1506: 'duke_397'
#   Found 13 positives and 13 negatives slices.
#     Processing slice 26/26 (index=74)
#   -> Dataset resized: now 9048 total slices.
#   Appended 26 slices for patient 'duke_397' (total written: 9048).
#
# Processing patient 134/1506: 'duke_398'
#   Found 13 positives and 13 negatives slices.
#     Processing slice 26/26 (index=59)
#   -> Dataset resized: now 9074 total slices.
#   Appended 26 slices for patient 'duke_398' (total written: 9074).
#
# Processing patient 135/1506: 'duke_399'
#   Found 18 positives and 18 negatives slices.
#     Processing slice 36/36 (index=92)
#   -> Dataset resized: now 9110 total slices.
#   Appended 36 slices for patient 'duke_399' (total written: 9110).
#
# Processing patient 136/1506: 'duke_400'
#   Found 55 positives and 55 negatives slices.
#     Processing slice 110/110 (index=133)
#   -> Dataset resized: now 9220 total slices.
#   Appended 110 slices for patient 'duke_400' (total written: 9220).
#
# Processing patient 137/1506: 'duke_406'
#   Found 16 positives and 16 negatives slices.
#     Processing slice 32/32 (index=154)
#   -> Dataset resized: now 9252 total slices.
#   Appended 32 slices for patient 'duke_406' (total written: 9252).
#
# Processing patient 138/1506: 'duke_407'
#   Found 55 positives and 55 negatives slices.
#     Processing slice 110/110 (index=149)
#   -> Dataset resized: now 9362 total slices.
#   Appended 110 slices for patient 'duke_407' (total written: 9362).
#
# Processing patient 139/1506: 'duke_408'
#   Found 7 positives and 7 negatives slices.
#     Processing slice 14/14 (index=124)
#   -> Dataset resized: now 9376 total slices.
#   Appended 14 slices for patient 'duke_408' (total written: 9376).
#
# Processing patient 140/1506: 'duke_412'
#   Found 37 positives and 37 negatives slices.
#     Processing slice 74/74 (index=151)
#   -> Dataset resized: now 9450 total slices.
#   Appended 74 slices for patient 'duke_412' (total written: 9450).
#
# Processing patient 141/1506: 'duke_414'
#   Found 43 positives and 43 negatives slices.
#     Processing slice 86/86 (index=155)
#   -> Dataset resized: now 9536 total slices.
#   Appended 86 slices for patient 'duke_414' (total written: 9536).
#
# Processing patient 142/1506: 'duke_420'
#   Found 95 positives and 95 negatives slices.
#   Processing slice 98/190 (index=3)    Processing slice 123/190 (index=124)    Processing slice 146/190 (index=147)    Processing slice 168/190 (index=169)
#   -> Dataset resized: now 9726 total slices.
#   Appended 190 slices for patient 'duke_420' (total written: 9726).
#
# Processing patient 143/1506: 'duke_424'
#   Found 17 positives and 17 negatives slices.
#     Processing slice 34/34 (index=85)
#   -> Dataset resized: now 9760 total slices.
#   Appended 34 slices for patient 'duke_424' (total written: 9760).
#
# Processing patient 144/1506: 'duke_428'
#   Found 21 positives and 21 negatives slices.
#     Processing slice 42/42 (index=121)
#   -> Dataset resized: now 9802 total slices.
#   Appended 42 slices for patient 'duke_428' (total written: 9802).
#
# Processing patient 145/1506: 'duke_429'
#   Found 36 positives and 36 negatives slices.
#     Processing slice 72/72 (index=109)
#   -> Dataset resized: now 9874 total slices.
#   Appended 72 slices for patient 'duke_429' (total written: 9874).
#
# Processing patient 146/1506: 'duke_431'
#   Found 13 positives and 13 negatives slices.
#     Processing slice 26/26 (index=77)
#   -> Dataset resized: now 9900 total slices.
#   Appended 26 slices for patient 'duke_431' (total written: 9900).
#
# Processing patient 147/1506: 'duke_435'
#   Found 26 positives and 26 negatives slices.
#     Processing slice 52/52 (index=103)
#   -> Dataset resized: now 9952 total slices.
#   Appended 52 slices for patient 'duke_435' (total written: 9952).
#
# Processing patient 148/1506: 'duke_437'
#   Found 86 positives and 86 negatives slices.
#     Processing slice 172/172 (index=174)
#   -> Dataset resized: now 10124 total slices.
#   Appended 172 slices for patient 'duke_437' (total written: 10124).
#
# Processing patient 149/1506: 'duke_438'
#   Found 23 positives and 23 negatives slices.
#     Processing slice 46/46 (index=122)
#   -> Dataset resized: now 10170 total slices.
#   Appended 46 slices for patient 'duke_438' (total written: 10170).
#
# Processing patient 150/1506: 'duke_441'
#   Found 40 positives and 40 negatives slices.
#     Processing slice 80/80 (index=108)
#   -> Dataset resized: now 10250 total slices.
#   Appended 80 slices for patient 'duke_441' (total written: 10250).
#
# Processing patient 151/1506: 'duke_444'
#   Found 33 positives and 33 negatives slices.
#     Processing slice 66/66 (index=133)
#   -> Dataset resized: now 10316 total slices.
#   Appended 66 slices for patient 'duke_444' (total written: 10316).
#
# Processing patient 152/1506: 'duke_454'
#   Found 35 positives and 35 negatives slices.
#     Processing slice 70/70 (index=106)
#   -> Dataset resized: now 10386 total slices.
#   Appended 70 slices for patient 'duke_454' (total written: 10386).
#
# Processing patient 153/1506: 'duke_457'
#   Found 23 positives and 23 negatives slices.
#     Processing slice 46/46 (index=88)
#   -> Dataset resized: now 10432 total slices.
#   Appended 46 slices for patient 'duke_457' (total written: 10432).
#
# Processing patient 154/1506: 'duke_464'
#   Found 32 positives and 32 negatives slices.
#     Processing slice 64/64 (index=99)
#   -> Dataset resized: now 10496 total slices.
#   Appended 64 slices for patient 'duke_464' (total written: 10496).
#
# Processing patient 155/1506: 'duke_465'
#   Found 19 positives and 19 negatives slices.
#     Processing slice 38/38 (index=117)
#   -> Dataset resized: now 10534 total slices.
#   Appended 38 slices for patient 'duke_465' (total written: 10534).
#
# Processing patient 156/1506: 'duke_468'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=156)
#   -> Dataset resized: now 10582 total slices.
#   Appended 48 slices for patient 'duke_468' (total written: 10582).
#
# Processing patient 157/1506: 'duke_470'
#   Found 20 positives and 20 negatives slices.
#     Processing slice 40/40 (index=159)
#   -> Dataset resized: now 10622 total slices.
#   Appended 40 slices for patient 'duke_470' (total written: 10622).
#
# Processing patient 158/1506: 'duke_474'
#   Found 42 positives and 42 negatives slices.
#     Processing slice 84/84 (index=175)
#   -> Dataset resized: now 10706 total slices.
#   Appended 84 slices for patient 'duke_474' (total written: 10706).
#
# Processing patient 159/1506: 'duke_480'
#   Found 31 positives and 31 negatives slices.
#     Processing slice 62/62 (index=105)
#   -> Dataset resized: now 10768 total slices.
#   Appended 62 slices for patient 'duke_480' (total written: 10768).
#
# Processing patient 160/1506: 'duke_482'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=134)
#   -> Dataset resized: now 10816 total slices.
#   Appended 48 slices for patient 'duke_482' (total written: 10816).
#
# Processing patient 161/1506: 'duke_486'
#   Found 22 positives and 22 negatives slices.
#     Processing slice 44/44 (index=101)
#   -> Dataset resized: now 10860 total slices.
#   Appended 44 slices for patient 'duke_486' (total written: 10860).
#
# Processing patient 162/1506: 'duke_489'
#   Found 56 positives and 56 negatives slices.
#     Processing slice 112/112 (index=142)
#   -> Dataset resized: now 10972 total slices.
#   Appended 112 slices for patient 'duke_489' (total written: 10972).
#
# Processing patient 163/1506: 'duke_491'
#   Found 27 positives and 27 negatives slices.
#     Processing slice 54/54 (index=142)
#   -> Dataset resized: now 11026 total slices.
#   Appended 54 slices for patient 'duke_491' (total written: 11026).
#
# Processing patient 164/1506: 'duke_501'
#   Found 26 positives and 26 negatives slices.
#     Processing slice 52/52 (index=105)
#   -> Dataset resized: now 11078 total slices.
#   Appended 52 slices for patient 'duke_501' (total written: 11078).
#
# Processing patient 165/1506: 'duke_506'
#   Found 14 positives and 14 negatives slices.
#     Processing slice 28/28 (index=107)
#   -> Dataset resized: now 11106 total slices.
#   Appended 28 slices for patient 'duke_506' (total written: 11106).
#
# Processing patient 166/1506: 'duke_507'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=71)
#   -> Dataset resized: now 11154 total slices.
#   Appended 48 slices for patient 'duke_507' (total written: 11154).
#
# Processing patient 167/1506: 'duke_508'
#   Found 39 positives and 39 negatives slices.
#     Processing slice 78/78 (index=93)
#   -> Dataset resized: now 11232 total slices.
#   Appended 78 slices for patient 'duke_508' (total written: 11232).
#
# Processing patient 168/1506: 'duke_512'
#   Found 38 positives and 38 negatives slices.
#     Processing slice 76/76 (index=127)
#   -> Dataset resized: now 11308 total slices.
#   Appended 76 slices for patient 'duke_512' (total written: 11308).
#
# Processing patient 169/1506: 'duke_514'
#   Found 21 positives and 21 negatives slices.
#     Processing slice 42/42 (index=126)
#   -> Dataset resized: now 11350 total slices.
#   Appended 42 slices for patient 'duke_514' (total written: 11350).
#
# Processing patient 170/1506: 'duke_517'
#   Found 43 positives and 43 negatives slices.
#     Processing slice 86/86 (index=104)
#   -> Dataset resized: now 11436 total slices.
#   Appended 86 slices for patient 'duke_517' (total written: 11436).
#
# Processing patient 171/1506: 'duke_521'
#   Found 33 positives and 33 negatives slices.
#     Processing slice 66/66 (index=133)
#   -> Dataset resized: now 11502 total slices.
#   Appended 66 slices for patient 'duke_521' (total written: 11502).
#
# Processing patient 172/1506: 'duke_525'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=111)
#   -> Dataset resized: now 11550 total slices.
#   Appended 48 slices for patient 'duke_525' (total written: 11550).
#
# Processing patient 173/1506: 'duke_527'
#   Found 71 positives and 71 negatives slices.
#     Processing slice 142/142 (index=188)
#   -> Dataset resized: now 11692 total slices.
#   Appended 142 slices for patient 'duke_527' (total written: 11692).
#
# Processing patient 174/1506: 'duke_530'
#   Found 32 positives and 32 negatives slices.
#     Processing slice 64/64 (index=85)
#   -> Dataset resized: now 11756 total slices.
#   Appended 64 slices for patient 'duke_530' (total written: 11756).
#
# Processing patient 175/1506: 'duke_534'
#   Found 18 positives and 18 negatives slices.
#     Processing slice 36/36 (index=137)
#   -> Dataset resized: now 11792 total slices.
#   Appended 36 slices for patient 'duke_534' (total written: 11792).
#
# Processing patient 176/1506: 'duke_535'
#   Found 122 positives and 64 negatives slices.
#     Processing slice 186/186 (index=191)
#   -> Dataset resized: now 11978 total slices.
#   Appended 186 slices for patient 'duke_535' (total written: 11978).
#
# Processing patient 177/1506: 'duke_539'
#   Found 62 positives and 62 negatives slices.
#     Processing slice 124/124 (index=147)
#   -> Dataset resized: now 12102 total slices.
#   Appended 124 slices for patient 'duke_539' (total written: 12102).
#
# Processing patient 178/1506: 'duke_541'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=88)
#   -> Dataset resized: now 12150 total slices.
#   Appended 48 slices for patient 'duke_541' (total written: 12150).
#
# Processing patient 179/1506: 'duke_543'
#   Found 69 positives and 69 negatives slices.
#     Processing slice 138/138 (index=173)
#   -> Dataset resized: now 12288 total slices.
#   Appended 138 slices for patient 'duke_543' (total written: 12288).
#
# Processing patient 180/1506: 'duke_545'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=84)
#   -> Dataset resized: now 12336 total slices.
#   Appended 48 slices for patient 'duke_545' (total written: 12336).
#
# Processing patient 181/1506: 'duke_546'
#   Found 41 positives and 41 negatives slices.
#     Processing slice 82/82 (index=104)
#   -> Dataset resized: now 12418 total slices.
#   Appended 82 slices for patient 'duke_546' (total written: 12418).
#
# Processing patient 182/1506: 'duke_552'
#   Found 14 positives and 14 negatives slices.
#     Processing slice 28/28 (index=121)
#   -> Dataset resized: now 12446 total slices.
#   Appended 28 slices for patient 'duke_552' (total written: 12446).
#
# Processing patient 183/1506: 'duke_558'
#   Found 17 positives and 17 negatives slices.
#     Processing slice 34/34 (index=67)
#   -> Dataset resized: now 12480 total slices.
#   Appended 34 slices for patient 'duke_558' (total written: 12480).
#
# Processing patient 184/1506: 'duke_559'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=136)
#   -> Dataset resized: now 12538 total slices.
#   Appended 58 slices for patient 'duke_559' (total written: 12538).
#
# Processing patient 185/1506: 'duke_560'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=73)
#   -> Dataset resized: now 12596 total slices.
#   Appended 58 slices for patient 'duke_560' (total written: 12596).
#
# Processing patient 186/1506: 'duke_562'
#   Found 27 positives and 27 negatives slices.
#     Processing slice 54/54 (index=104)
#   -> Dataset resized: now 12650 total slices.
#   Appended 54 slices for patient 'duke_562' (total written: 12650).
#
# Processing patient 187/1506: 'duke_567'
#   Found 52 positives and 52 negatives slices.
#     Processing slice 104/104 (index=185)
#   -> Dataset resized: now 12754 total slices.
#   Appended 104 slices for patient 'duke_567' (total written: 12754).
#
# Processing patient 188/1506: 'duke_568'
#   Found 25 positives and 25 negatives slices.
#     Processing slice 50/50 (index=136)
#   -> Dataset resized: now 12804 total slices.
#   Appended 50 slices for patient 'duke_568' (total written: 12804).
#
# Processing patient 189/1506: 'duke_573'
#   Found 23 positives and 23 negatives slices.
#     Processing slice 46/46 (index=70)
#   -> Dataset resized: now 12850 total slices.
#   Appended 46 slices for patient 'duke_573' (total written: 12850).
#
# Processing patient 190/1506: 'duke_577'
#   Found 42 positives and 42 negatives slices.
#     Processing slice 84/84 (index=159)
#   -> Dataset resized: now 12934 total slices.
#   Appended 84 slices for patient 'duke_577' (total written: 12934).
#
# Processing patient 191/1506: 'duke_585'
#   Found 16 positives and 16 negatives slices.
#     Processing slice 32/32 (index=75)
#   -> Dataset resized: now 12966 total slices.
#   Appended 32 slices for patient 'duke_585' (total written: 12966).
#
# Processing patient 192/1506: 'duke_590'
#   Found 45 positives and 45 negatives slices.
#     Processing slice 90/90 (index=134)
#   -> Dataset resized: now 13056 total slices.
#   Appended 90 slices for patient 'duke_590' (total written: 13056).
#
# Processing patient 193/1506: 'duke_592'
#   Found 66 positives and 66 negatives slices.
#     Processing slice 132/132 (index=132)
#   -> Dataset resized: now 13188 total slices.
#   Appended 132 slices for patient 'duke_592' (total written: 13188).
#
# Processing patient 194/1506: 'duke_595'
#   Found 23 positives and 23 negatives slices.
#     Processing slice 46/46 (index=95)
#   -> Dataset resized: now 13234 total slices.
#   Appended 46 slices for patient 'duke_595' (total written: 13234).
#
# Processing patient 195/1506: 'duke_597'
#   Found 44 positives and 44 negatives slices.
#     Processing slice 88/88 (index=111)
#   -> Dataset resized: now 13322 total slices.
#   Appended 88 slices for patient 'duke_597' (total written: 13322).
#
# Processing patient 196/1506: 'duke_605'
#   Found 27 positives and 27 negatives slices.
#     Processing slice 54/54 (index=143)
#   -> Dataset resized: now 13376 total slices.
#   Appended 54 slices for patient 'duke_605' (total written: 13376).
#
# Processing patient 197/1506: 'duke_607'
#   Found 21 positives and 21 negatives slices.
#     Processing slice 42/42 (index=108)
#   -> Dataset resized: now 13418 total slices.
#   Appended 42 slices for patient 'duke_607' (total written: 13418).
#
# Processing patient 198/1506: 'duke_609'
#   Found 22 positives and 22 negatives slices.
#     Processing slice 44/44 (index=93)
#   -> Dataset resized: now 13462 total slices.
#   Appended 44 slices for patient 'duke_609' (total written: 13462).
#
# Processing patient 199/1506: 'duke_610'
#   Found 13 positives and 13 negatives slices.
#     Processing slice 26/26 (index=144)
#   -> Dataset resized: now 13488 total slices.
#   Appended 26 slices for patient 'duke_610' (total written: 13488).
#
# Processing patient 200/1506: 'duke_612'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=160)
#   -> Dataset resized: now 13546 total slices.
#   Appended 58 slices for patient 'duke_612' (total written: 13546).
# ...
#
# Processing patient 1441/1506: 'ispy2_999264'
#   Found 29 positives and 29 negatives slices.
#     Processing slice 58/58 (index=72)
#   -> Dataset resized: now 106065 total slices.
#   Appended 58 slices for patient 'ispy2_999264' (total written: 106065).
#
# Processing patient 1442/1506: 'ispy2_999733'
#   Found 36 positives and 36 negatives slices.
#     Processing slice 72/72 (index=102)
#   -> Dataset resized: now 106137 total slices.
#   Appended 72 slices for patient 'ispy2_999733' (total written: 106137).
#
# Processing patient 1443/1506: 'nact_01'
#   Found 38 positives and 38 negatives slices.
#     Processing slice 76/76 (index=112)
#   -> Dataset resized: now 106213 total slices.
#   Appended 76 slices for patient 'nact_01' (total written: 106213).
#
# Processing patient 1444/1506: 'nact_02'
#   Found 46 positives and 46 negatives slices.
#     Processing slice 92/92 (index=110)
#   -> Dataset resized: now 106305 total slices.
#   Appended 92 slices for patient 'nact_02' (total written: 106305).
#
# Processing patient 1445/1506: 'nact_03'
#   Found 10 positives and 10 negatives slices.
#     Processing slice 20/20 (index=49)
#   -> Dataset resized: now 106325 total slices.
#   Appended 20 slices for patient 'nact_03' (total written: 106325).
#
# Processing patient 1446/1506: 'nact_04'
#   Found 60 positives and 60 negatives slices.
#     Processing slice 120/120 (index=130)
#   -> Dataset resized: now 106445 total slices.
#   Appended 120 slices for patient 'nact_04' (total written: 106445).
#
# Processing patient 1447/1506: 'nact_06'
#   Found 76 positives and 43 negatives slices.
#     Processing slice 119/119 (index=118)
#   -> Dataset resized: now 106564 total slices.
#   Appended 119 slices for patient 'nact_06' (total written: 106564).
#
# Processing patient 1448/1506: 'nact_07'
#   Found 26 positives and 26 negatives slices.
#     Processing slice 52/52 (index=109)
#   -> Dataset resized: now 106616 total slices.
#   Appended 52 slices for patient 'nact_07' (total written: 106616).
#
# Processing patient 1449/1506: 'nact_08'
#   Found 56 positives and 56 negatives slices.
#     Processing slice 112/112 (index=118)
#   -> Dataset resized: now 106728 total slices.
#   Appended 112 slices for patient 'nact_08' (total written: 106728).
#
# Processing patient 1450/1506: 'nact_09'
#   Found 62 positives and 55 negatives slices.
#     Processing slice 117/117 (index=118)
#   -> Dataset resized: now 106845 total slices.
#   Appended 117 slices for patient 'nact_09' (total written: 106845).
#
# Processing patient 1451/1506: 'nact_11'
#   Found 28 positives and 28 negatives slices.
#     Processing slice 56/56 (index=105)
#   -> Dataset resized: now 106901 total slices.
#   Appended 56 slices for patient 'nact_11' (total written: 106901).
#
# Processing patient 1452/1506: 'nact_12'
#   Found 122 positives and 21 negatives slices.
#     Processing slice 143/143 (index=142)
#   -> Dataset resized: now 107044 total slices.
#   Appended 143 slices for patient 'nact_12' (total written: 107044).
#
# Processing patient 1453/1506: 'nact_13'
#   Found 88 positives and 29 negatives slices.
#     Processing slice 117/117 (index=118)
#   -> Dataset resized: now 107161 total slices.
#   Appended 117 slices for patient 'nact_13' (total written: 107161).
#
# Processing patient 1454/1506: 'nact_14'
#   Found 54 positives and 54 negatives slices.
#     Processing slice 108/108 (index=115)
#   -> Dataset resized: now 107269 total slices.
#   Appended 108 slices for patient 'nact_14' (total written: 107269).
#
# Processing patient 1455/1506: 'nact_15'
#   Found 20 positives and 20 negatives slices.
#     Processing slice 40/40 (index=75)
#   -> Dataset resized: now 107309 total slices.
#   Appended 40 slices for patient 'nact_15' (total written: 107309).
#
# Processing patient 1456/1506: 'nact_17'
#   Found 34 positives and 34 negatives slices.
#     Processing slice 68/68 (index=71)
#   -> Dataset resized: now 107377 total slices.
#   Appended 68 slices for patient 'nact_17' (total written: 107377).
#
# Processing patient 1457/1506: 'nact_18'
#   Found 46 positives and 46 negatives slices.
#     Processing slice 92/92 (index=116)
#   -> Dataset resized: now 107469 total slices.
#   Appended 92 slices for patient 'nact_18' (total written: 107469).
#
# Processing patient 1458/1506: 'nact_19'
#   Found 26 positives and 26 negatives slices.
#     Processing slice 52/52 (index=85)
#   -> Dataset resized: now 107521 total slices.
#   Appended 52 slices for patient 'nact_19' (total written: 107521).
#
# Processing patient 1459/1506: 'nact_20'
#   Found 18 positives and 18 negatives slices.
#     Processing slice 36/36 (index=79)
#   -> Dataset resized: now 107557 total slices.
#   Appended 36 slices for patient 'nact_20' (total written: 107557).
#
# Processing patient 1460/1506: 'nact_21'
#   Found 32 positives and 32 negatives slices.
#     Processing slice 64/64 (index=74)
#   -> Dataset resized: now 107621 total slices.
#   Appended 64 slices for patient 'nact_21' (total written: 107621).
#
# Processing patient 1461/1506: 'nact_22'
#   Found 16 positives and 16 negatives slices.
#     Processing slice 32/32 (index=99)
#   -> Dataset resized: now 107653 total slices.
#   Appended 32 slices for patient 'nact_22' (total written: 107653).
#
# Processing patient 1462/1506: 'nact_23'
#   Found 72 positives and 53 negatives slices.
#     Processing slice 125/125 (index=126)
#   -> Dataset resized: now 107778 total slices.
#   Appended 125 slices for patient 'nact_23' (total written: 107778).
#
# Processing patient 1463/1506: 'nact_24'
#   Found 42 positives and 42 negatives slices.
#     Processing slice 84/84 (index=117)
#   -> Dataset resized: now 107862 total slices.
#   Appended 84 slices for patient 'nact_24' (total written: 107862).
#
# Processing patient 1464/1506: 'nact_25'
#   Found 64 positives and 55 negatives slices.
#     Processing slice 119/119 (index=118)
#   -> Dataset resized: now 107981 total slices.
#   Appended 119 slices for patient 'nact_25' (total written: 107981).
#
# Processing patient 1465/1506: 'nact_26'
#   Found 18 positives and 18 negatives slices.
#     Processing slice 36/36 (index=103)
#   -> Dataset resized: now 108017 total slices.
#   Appended 36 slices for patient 'nact_26' (total written: 108017).
#
# Processing patient 1466/1506: 'nact_27'
#   Found 20 positives and 20 negatives slices.
#     Processing slice 40/40 (index=93)
#   -> Dataset resized: now 108057 total slices.
#   Appended 40 slices for patient 'nact_27' (total written: 108057).
#
# Processing patient 1467/1506: 'nact_28'
#   Found 64 positives and 51 negatives slices.
#     Processing slice 115/115 (index=118)
#   -> Dataset resized: now 108172 total slices.
#   Appended 115 slices for patient 'nact_28' (total written: 108172).
#
# Processing patient 1468/1506: 'nact_29'
#   Found 74 positives and 45 negatives slices.
#     Processing slice 119/119 (index=118)
#   -> Dataset resized: now 108291 total slices.
#   Appended 119 slices for patient 'nact_29' (total written: 108291).
#
# Processing patient 1469/1506: 'nact_30'
#   Found 92 positives and 27 negatives slices.
#     Processing slice 119/119 (index=118)
#   -> Dataset resized: now 108410 total slices.
#   Appended 119 slices for patient 'nact_30' (total written: 108410).
#
# Processing patient 1470/1506: 'nact_31'
#   Found 34 positives and 34 negatives slices.
#     Processing slice 68/68 (index=93)
#   -> Dataset resized: now 108478 total slices.
#   Appended 68 slices for patient 'nact_31' (total written: 108478).
#
# Processing patient 1471/1506: 'nact_32'
#   Found 28 positives and 28 negatives slices.
#     Processing slice 56/56 (index=87)
#   -> Dataset resized: now 108534 total slices.
#   Appended 56 slices for patient 'nact_32' (total written: 108534).
#
# Processing patient 1472/1506: 'nact_33'
#   Found 38 positives and 38 negatives slices.
#     Processing slice 76/76 (index=114)
#   -> Dataset resized: now 108610 total slices.
#   Appended 76 slices for patient 'nact_33' (total written: 108610).
#
# Processing patient 1473/1506: 'nact_34'
#   Found 98 positives and 21 negatives slices.
#     Processing slice 119/119 (index=118)
#   -> Dataset resized: now 108729 total slices.
#   Appended 119 slices for patient 'nact_34' (total written: 108729).
#
# Processing patient 1474/1506: 'nact_35'
#   Found 32 positives and 32 negatives slices.
#     Processing slice 64/64 (index=98)
#   -> Dataset resized: now 108793 total slices.
#   Appended 64 slices for patient 'nact_35' (total written: 108793).
#
# Processing patient 1475/1506: 'nact_36'
#   Found 18 positives and 18 negatives slices.
#     Processing slice 36/36 (index=75)
#   -> Dataset resized: now 108829 total slices.
#   Appended 36 slices for patient 'nact_36' (total written: 108829).
#
# Processing patient 1476/1506: 'nact_37'
#   Found 30 positives and 30 negatives slices.
#     Processing slice 60/60 (index=68)
#   -> Dataset resized: now 108889 total slices.
#   Appended 60 slices for patient 'nact_37' (total written: 108889).
#
# Processing patient 1477/1506: 'nact_39'
#   Found 36 positives and 36 negatives slices.
#     Processing slice 72/72 (index=111)
#   -> Dataset resized: now 108961 total slices.
#   Appended 72 slices for patient 'nact_39' (total written: 108961).
#
# Processing patient 1478/1506: 'nact_40'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=77)
#   -> Dataset resized: now 109009 total slices.
#   Appended 48 slices for patient 'nact_40' (total written: 109009).
#
# Processing patient 1479/1506: 'nact_41'
#   Found 36 positives and 36 negatives slices.
#     Processing slice 72/72 (index=112)
#   -> Dataset resized: now 109081 total slices.
#   Appended 72 slices for patient 'nact_41' (total written: 109081).
#
# Processing patient 1480/1506: 'nact_42'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=91)
#   -> Dataset resized: now 109129 total slices.
#   Appended 48 slices for patient 'nact_42' (total written: 109129).
#
# Processing patient 1481/1506: 'nact_43'
#   Found 33 positives and 33 negatives slices.
#     Processing slice 66/66 (index=108)
#   -> Dataset resized: now 109195 total slices.
#   Appended 66 slices for patient 'nact_43' (total written: 109195).
#
# Processing patient 1482/1506: 'nact_44'
#   Found 36 positives and 36 negatives slices.
#     Processing slice 72/72 (index=78)
#   -> Dataset resized: now 109267 total slices.
#   Appended 72 slices for patient 'nact_44' (total written: 109267).
#
# Processing patient 1483/1506: 'nact_45'
#   Found 26 positives and 26 negatives slices.
#     Processing slice 52/52 (index=97)
#   -> Dataset resized: now 109319 total slices.
#   Appended 52 slices for patient 'nact_45' (total written: 109319).
#
# Processing patient 1484/1506: 'nact_46'
#   Found 20 positives and 20 negatives slices.
#     Processing slice 40/40 (index=86)
#   -> Dataset resized: now 109359 total slices.
#   Appended 40 slices for patient 'nact_46' (total written: 109359).
#
# Processing patient 1485/1506: 'nact_47'
#   Found 20 positives and 20 negatives slices.
#     Processing slice 40/40 (index=97)
#   -> Dataset resized: now 109399 total slices.
#   Appended 40 slices for patient 'nact_47' (total written: 109399).
#
# Processing patient 1486/1506: 'nact_48'
#   Found 55 positives and 55 negatives slices.
#     Processing slice 110/110 (index=134)
#   -> Dataset resized: now 109509 total slices.
#   Appended 110 slices for patient 'nact_48' (total written: 109509).
#
# Processing patient 1487/1506: 'nact_49'
#   Found 32 positives and 32 negatives slices.
#     Processing slice 64/64 (index=80)
#   -> Dataset resized: now 109573 total slices.
#   Appended 64 slices for patient 'nact_49' (total written: 109573).
#
# Processing patient 1488/1506: 'nact_50'
#   Found 10 positives and 10 negatives slices.
#     Processing slice 20/20 (index=73)
#   -> Dataset resized: now 109593 total slices.
#   Appended 20 slices for patient 'nact_50' (total written: 109593).
#
# Processing patient 1489/1506: 'nact_51'
#   Found 34 positives and 34 negatives slices.
#     Processing slice 68/68 (index=97)
#   -> Dataset resized: now 109661 total slices.
#   Appended 68 slices for patient 'nact_51' (total written: 109661).
#
# Processing patient 1490/1506: 'nact_52'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=67)
#   -> Dataset resized: now 109709 total slices.
#   Appended 48 slices for patient 'nact_52' (total written: 109709).
#
# Processing patient 1491/1506: 'nact_53'
#   Found 22 positives and 22 negatives slices.
#     Processing slice 44/44 (index=91)
#   -> Dataset resized: now 109753 total slices.
#   Appended 44 slices for patient 'nact_53' (total written: 109753).
#
# Processing patient 1492/1506: 'nact_54'
#   Found 22 positives and 22 negatives slices.
#     Processing slice 44/44 (index=117)
#   -> Dataset resized: now 109797 total slices.
#   Appended 44 slices for patient 'nact_54' (total written: 109797).
#
# Processing patient 1493/1506: 'nact_55'
#   Found 35 positives and 35 negatives slices.
#     Processing slice 70/70 (index=124)
#   -> Dataset resized: now 109867 total slices.
#   Appended 70 slices for patient 'nact_55' (total written: 109867).
#
# Processing patient 1494/1506: 'nact_56'
#   Found 16 positives and 16 negatives slices.
#     Processing slice 32/32 (index=56)
#   -> Dataset resized: now 109899 total slices.
#   Appended 32 slices for patient 'nact_56' (total written: 109899).
#
# Processing patient 1495/1506: 'nact_57'
#   Found 72 positives and 41 negatives slices.
#     Processing slice 113/113 (index=118)
#   -> Dataset resized: now 110012 total slices.
#   Appended 113 slices for patient 'nact_57' (total written: 110012).
#
# Processing patient 1496/1506: 'nact_58'
#   Found 58 positives and 58 negatives slices.
#     Processing slice 116/116 (index=118)
#   -> Dataset resized: now 110128 total slices.
#   Appended 116 slices for patient 'nact_58' (total written: 110128).
#
# Processing patient 1497/1506: 'nact_59'
#   Found 22 positives and 22 negatives slices.
#     Processing slice 44/44 (index=79)
#   -> Dataset resized: now 110172 total slices.
#   Appended 44 slices for patient 'nact_59' (total written: 110172).
#
# Processing patient 1498/1506: 'nact_60'
#   Found 19 positives and 19 negatives slices.
#     Processing slice 38/38 (index=87)
#   -> Dataset resized: now 110210 total slices.
#   Appended 38 slices for patient 'nact_60' (total written: 110210).
#
# Processing patient 1499/1506: 'nact_61'
#   Found 36 positives and 36 negatives slices.
#     Processing slice 72/72 (index=94)
#   -> Dataset resized: now 110282 total slices.
#   Appended 72 slices for patient 'nact_61' (total written: 110282).
#
# Processing patient 1500/1506: 'nact_62'
#   Found 34 positives and 34 negatives slices.
#     Processing slice 68/68 (index=84)
#   -> Dataset resized: now 110350 total slices.
#   Appended 68 slices for patient 'nact_62' (total written: 110350).
#
# Processing patient 1501/1506: 'nact_63'
#   Found 62 positives and 57 negatives slices.
#     Processing slice 119/119 (index=118)
#   -> Dataset resized: now 110469 total slices.
#   Appended 119 slices for patient 'nact_63' (total written: 110469).
#
# Processing patient 1502/1506: 'nact_64'
#   Found 46 positives and 46 negatives slices.
#     Processing slice 92/92 (index=106)
#   -> Dataset resized: now 110561 total slices.
#   Appended 92 slices for patient 'nact_64' (total written: 110561).
#
# Processing patient 1503/1506: 'nact_65'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=78)
#   -> Dataset resized: now 110609 total slices.
#   Appended 48 slices for patient 'nact_65' (total written: 110609).
#
# Processing patient 1504/1506: 'nact_66'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=114)
#   -> Dataset resized: now 110657 total slices.
#   Appended 48 slices for patient 'nact_66' (total written: 110657).
#
# Processing patient 1505/1506: 'nact_67'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=76)
#   -> Dataset resized: now 110705 total slices.
#   Appended 48 slices for patient 'nact_67' (total written: 110705).
#
# Processing patient 1506/1506: 'nact_68'
#   Found 24 positives and 24 negatives slices.
#     Processing slice 48/48 (index=62)
#   -> Dataset resized: now 110753 total slices.
#   Appended 48 slices for patient 'nact_68' (total written: 110753).
#
# HDF5 container creation complete.
